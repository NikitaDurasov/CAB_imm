# %%
import matplotlib.pyplot as plt 
import sys 
sys.path.insert(0, '/home/ndurasov/cloned_ig_cluster_splitter/ig_cluster_splitter/scripts')
import func_tools
reload(func_tools)
from collections import Counter
import numpy as np
import pandas as pd 
import json 
import os 
import re

# %%
def sens_prec_plot(igrec_json, test_json, axe):
    axe.plot(test_json['reference_based']['__data_precision'], test_json['reference_based']['__data_sensitivity'], label='test', c='r')
    axe.plot(igrec_json['reference_based']['__data_precision'], igrec_json['reference_based']['__data_sensitivity'], label='igrec', c='b')
    
    axe.scatter(test_json['reference_based']['__data_precision'], test_json['reference_based']['__data_sensitivity'], s=5, c='r')
    axe.scatter(igrec_json['reference_based']['__data_precision'], igrec_json['reference_based']['__data_sensitivity'], s=5, c='b')
    
    axe.scatter(test_json['reference_based']['__data_precision'][4], 
                test_json['reference_based']['__data_sensitivity'][4], s=20, c='k')
    axe.scatter(igrec_json['reference_based']['__data_precision'][4], 
                igrec_json['reference_based']['__data_sensitivity'][4], s=20, c='k')

# %%
igrec_rcm = ft.read_rcm('data/final_repertoire.rcm')
id_dict = ft.id_to_read('data/input3.fa')
reference_rcm = ft.read_rcm('data/repertoire3.rcm')
reference = ft.read_repertoire('data/repertoire3.fa')

clusters = ft.construct_clusters(igrec_rcm, id_dict)

# %%
ans = ft.reference_classification(clusters, reference_rcm, reference, id_dict)

# %%
res = []
for perc in ans[1].values():
    res.append(perc)

# %%
plt.hist(np.array(res)[:,1])
plt.hist(np.array(res)[:,0], alpha=0.5)
plt.show()

# %%
ans2 = ft.simple_clusters_classification(clusters, reference)
# Out:
# 0  reads checked
# 1000  reads checked
# 2000  reads checked
# 3000  reads checked
# 4000  reads checked
# 5000  reads checked
# 6000  reads checked
# 7000  reads checked
# 8000  reads checked
# 9000  reads checked
# 10000  reads checked
# 11000  reads checked
# 12000  reads checked
# 13000  reads checked
# 14000  reads checked
# 15000  reads checked
# 16000  reads checked
# 17000  reads checked
# 18000  reads checked
# 19000  reads checked
# 20000  reads checked
# 21000  reads checked
# 22000  reads checked
# 23000  reads checked
# 24000  reads checked
# 25000  reads checked
# 26000  reads checked
# 27000  reads checked
# 28000  reads checked

# %%
reload(ft)
# Out:
# <module 'func_tools' from 'func_tools.py'>

# %%
len(set(ans2.keys()).intersection(set(dict(filter(lambda x: x[1] == 1, ans[0].items())).keys())))
# Out:
# 98

# %%
f = plt.figure()

# %%
f.savefig?

# %%
base = '/Bmo/orange_nikita/GMC_compilation/splitted/'
regex = re.compile('.*_igquast+$')
dirs = filter(regex.match, os.listdir('/Bmo/orange_nikita/GMC_compilation/splitted/'))
fig = plt.figure()
fig, axes = plt.subplots(nrows=len(dirs), ncols=1, figsize=(10,80))

for i, dataset in enumerate(dirs):
    igrec_json = json.load(open(base + dataset +'/igrec_origin/igquast.json', 'r'))
    test_json = json.load(open(base + dataset + '/igrec_splitted/igquast.json', 'r'))
    sens_prec_plot(igrec_json, test_json, axes[i])
    axes[i].set_xlabel('Precision')
    axes[i].set_ylabel('Sensitivity')
    axes[i].set_title(dataset)
    axes[i].set_xlim((0,1))
    axes[i].set_ylim((0,1))
plt.show()

fig.savefig('GMC.pdf', format='pdf')

# %%
base = '/Bmo/orange_nikita/IDO_compilation/splitted/'
regex = re.compile('.*_igquast+$')
dirs = filter(regex.match, os.listdir(base))
fig = plt.figure()
fig, axes = plt.subplots(nrows=len(dirs), ncols=1, figsize=(10,80))

for i, dataset in enumerate(dirs):
    igrec_json = json.load(open(base + dataset +'/igrec_origin/igquast.json', 'r'))
    test_json = json.load(open(base + dataset + '/igrec_splitted/igquast.json', 'r'))
    sens_prec_plot(igrec_json, test_json, axes[i])
    axes[i].set_xlabel('Precision')
    axes[i].set_ylabel('Sensitivity')
    axes[i].set_title(dataset)
    axes[i].set_xlim((0,1))
    axes[i].set_ylim((0,1))
plt.show()

fig.savefig('IDO.pdf', format='pdf')

# %%
base = '/Bmo/orange_nikita/AGE_compilation/splitted/'
regex = re.compile('.*_igquast+$')
dirs = filter(regex.match, os.listdir(base))
fig = plt.figure()
fig, axes = plt.subplots(nrows=len(dirs), ncols=1, figsize=(10,80))

for i, dataset in enumerate(dirs):
    igrec_json = json.load(open(base + dataset +'/igrec_origin/igquast.json', 'r'))
    test_json = json.load(open(base + dataset + '/igrec_splitted/igquast.json', 'r'))
    sens_prec_plot(igrec_json, test_json, axes[i])
    axes[i].set_xlabel('Precision')
    axes[i].set_ylabel('Sensitivity')
    axes[i].set_title(dataset)
    axes[i].set_xlim((0,1))
    axes[i].set_ylim((0,1))
plt.show()

fig.savefig('AGE.pdf', format='pdf')

# %%
base = '/Bmo/orange_nikita/FLU_compilation/splitted/'
regex = re.compile('.*_igquast+$')
dirs = filter(regex.match, os.listdir(base))
fig = plt.figure()
fig, axes = plt.subplots(nrows=len(dirs), ncols=1, figsize=(10,200))

for i, dataset in enumerate(dirs):
    igrec_json = json.load(open(base + dataset +'/igrec_origin/igquast.json', 'r'))
    test_json = json.load(open(base + dataset + '/igrec_splitted/igquast.json', 'r'))
    sens_prec_plot(igrec_json, test_json, axes[i])
    axes[i].set_xlabel('Precision')
    axes[i].set_ylabel('Sensitivity')
    axes[i].set_title(dataset)
    axes[i].set_xlim((0,1))
    axes[i].set_ylim((0,1))
plt.show()

#fig.savefig('FLU.pdf', format='pdf')

# %%
df = pd.read_csv('/Bmo/orange_nikita/AGE_compilation/AGE1_dataset_2.csv')

# %%
df = df[df['size'] > 10]

# %%
plt.scatter(df['value1'] * df['size'], df['size'], c=df['quality_imp'])
plt.show()

# %%
input_reads = '/Bmo/orange_nikita/IDO_compilation/IDO_11_IG/input3.fa'
ref_rcm_file = '/Bmo/orange_nikita/IDO_compilation/IDO_11_IG/repertoire3.rcm'
cons_rmc_nsp_file = '/Bmo/orange_nikita/IDO_compilation/IDO_11_IG/final_repertoire.rcm'
cons_rcm_file = '/Bmo/orange_nikita/IDO_compilation/splitted/IDO_11_IG_splitted.rcm'

# %%
id_dict = func_tools.id_to_read(input_reads)

ref_rcm = func_tools.read_rcm(ref_rcm_file)

cons_rcm = func_tools.read_rcm(cons_rmc_nsp_file)

ref_clusters = func_tools.construct_clusters(ref_rcm, id_dict)

cons_clusters = func_tools.construct_clusters(cons_rcm, id_dict)

rep = func_tools.clusters2rep(ref_clusters)

cons_rep = func_tools.clusters2rep(cons_clusters)

res = func_tools.find_unrecognized_clusters(rep, cons_rep)

df = func_tools.build_df(input_reads, ref_rcm_file, threshold=0)
# Out:
# build_df started
# calculation step
# /home/ndurasov/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:135: RuntimeWarning: Degrees of freedom <= 0 for slice
#   keepdims=keepdims)
# /home/ndurasov/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:105: RuntimeWarning: invalid value encountered in true_divide
#   arrmean, rcount, out=arrmean, casting='unsafe', subok=False)
# /home/ndurasov/anaconda2/lib/python2.7/site-packages/numpy/core/_methods.py:127: RuntimeWarning: invalid value encountered in double_scalars
#   ret = ret.dtype.type(ret / rcount)
# parsing step
# context step
# mutation step
# building succeeded

# %%
1. * len(df[df['size'] < 10]) / len(df)
# Out:
# 0.9421983698835711

# %%
plt.hist(df.ix[map(int, res)]['size'], bins=50)
plt.xlim((-5, 20))
plt.show()
# Out:
# /home/ndurasov/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
res_perc = []
for i in range(5, 25):
    clusters_with_i_size = map(str, df[df['size'] == i].index)
    unrecognized_with_i_size = [] 
    for cluster_id in clusters_with_i_size:
        if cluster_id in res:
            unrecognized_with_i_size.append(cluster_id)
    res_perc.append(1.0 * len(unrecognized_with_i_size)/len(clusters_with_i_size))
    
plt.bar(range(5,25), res_perc)
plt.xticks(range(5,25), range(5,25))
plt.show()

# %%
input_reads = '/Bmo/orange_nikita/IDO_compilation/IDO_14_IG/input3.fa'
ref_rcm_file = '/Bmo/orange_nikita/IDO_compilation/IDO_14_IG/repertoire3.rcm'
cons_rmc_nsp_file = '/Bmo/orange_nikita/IDO_compilation/IDO_14_IG/final_repertoire.rcm'
cons_rcm_file = '/Bmo/orange_nikita/IDO_compilation/splitted/IDO_14
_IG_splitted.rcm'

# %%
id_dict = func_tools.id_to_read(input_reads)

ref_rcm = func_tools.read_rcm(ref_rcm_file)

cons_rcm = func_tools.read_rcm(cons_rcm_file)

ref_clusters = func_tools.construct_clusters(ref_rcm, id_dict)

cons_clusters = func_tools.construct_clusters(cons_rcm, id_dict)

rep = func_tools.clusters2rep(ref_clusters)

cons_rep = func_tools.clusters2rep(cons_clusters)

res = func_tools.find_unrecognized_clusters(rep, cons_rep)

df = func_tools.build_df(input_reads, ref_rcm_file, threshold=0)
# Out:
# build_df started
# calculation step
# parsing step
# context step
# mutation step
# building succeeded

# %%
1. * len(df[df['size'] < 10]) / len(df)
# Out:
# 0.7800061472260642

# %%
plt.hist(df.ix[map(int, res)]['size'], bins=150)
plt.xlim((-5, 20))
plt.show()
# Out:
# /home/ndurasov/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
res_perc = []
for i in range(5, 25):
    clusters_with_i_size = map(str, df[df['size'] == i].index)
    unrecognized_with_i_size = [] 
    for cluster_id in clusters_with_i_size:
        if cluster_id in res:
            unrecognized_with_i_size.append(cluster_id)
    res_perc.append(1.0 * len(unrecognized_with_i_size)/len(clusters_with_i_size))
    
plt.bar(range(5,25), res_perc)
plt.xticks(range(5,25), range(5,25))
plt.show()

# %%
input_reads = '/Bmo/orange_nikita/IDO_compilation/IDO_12_IG/input3.fa'
ref_rcm_file = '/Bmo/orange_nikita/IDO_compilation/IDO_12_IG/repertoire3.rcm'
cons_rmc_nsp_file = '/Bmo/orange_nikita/IDO_compilation/IDO_12_IG/final_repertoire.rcm'
cons_rcm_file = '/Bmo/orange_nikita/IDO_compilation/splitted/IDO_12_IG_splitted.rcm'

# %%
id_dict = func_tools.id_to_read(input_reads)

ref_rcm = func_tools.read_rcm(ref_rcm_file)

cons_rcm = func_tools.read_rcm(cons_rcm_file)

ref_clusters = func_tools.construct_clusters(ref_rcm, id_dict)

cons_clusters = func_tools.construct_clusters(cons_rcm, id_dict)

rep = func_tools.clusters2rep(ref_clusters)

cons_rep = func_tools.clusters2rep(cons_clusters)

res = func_tools.find_unrecognized_clusters(rep, cons_rep)

df = func_tools.build_df(input_reads, ref_rcm_file, threshold=0)
# Out:
# build_df started
# calculation step
# parsing step
# building succeeded

# %%
1. * len(df[df['size'] < 10]) / len(df)
# Out:
# 0.93322844470968

# %%
plt.hist(df.ix[map(int, res)]['size'], bins=150)
plt.xlim((-5, 20))
plt.show()
# Out:
# /home/ndurasov/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
res_perc = []
for i in range(5, 25):
    clusters_with_i_size = map(str, df[df['size'] == i].index)
    unrecognized_with_i_size = [] 
    for cluster_id in clusters_with_i_size:
        if cluster_id in res:
            unrecognized_with_i_size.append(cluster_id)
    res_perc.append(1.0 * len(unrecognized_with_i_size)/len(clusters_with_i_size))
    
plt.bar(range(5,25), res_perc)
plt.xticks(range(5,25), range(5,25))
plt.show()

# %%
input_reads = '/Bmo/orange_nikita/IDO_compilation/IDO_13_IG/input3.fa'
ref_rcm_file = '/Bmo/orange_nikita/IDO_compilation/IDO_13_IG/repertoire3.rcm'
cons_rmc_nsp_file = '/Bmo/orange_nikita/IDO_compilation/IDO_13_IG/final_repertoire.rcm'
cons_rcm_file = '/Bmo/orange_nikita/IDO_compilation/splitted/IDO_13_IG_splitted.rcm'

# %%
id_dict = func_tools.id_to_read(input_reads)

ref_rcm = func_tools.read_rcm(ref_rcm_file)

cons_rcm = func_tools.read_rcm(cons_rcm_file)

ref_clusters = func_tools.construct_clusters(ref_rcm, id_dict)

cons_clusters = func_tools.construct_clusters(cons_rcm, id_dict)

rep = func_tools.clusters2rep(ref_clusters)

cons_rep = func_tools.clusters2rep(cons_clusters)

res = func_tools.find_unrecognized_clusters(rep, cons_rep)

df = func_tools.build_df(input_reads, ref_rcm_file, threshold=0)
# Out:
# build_df started
# calculation step
# parsing step
# building succeeded

# %%
1. * len(df[df['size'] < 10]) / len(df)
# Out:
# 0.8526743239399319

# %%
plt.hist(df.ix[map(int, res)]['size'], bins=150)
plt.xlim((-5, 20))
plt.show()
# Out:
# /home/ndurasov/.local/lib/python2.7/site-packages/ipykernel_launcher.py:1: DeprecationWarning:
# .ix is deprecated. Please use
# .loc for label based indexing or
# .iloc for positional indexing
#
# See the documentation here:
# http://pandas.pydata.org/pandas-docs/stable/indexing.html#ix-indexer-is-deprecated
#   """Entry point for launching an IPython kernel.

# %%
res_perc = []
for i in range(5, 25):
    clusters_with_i_size = map(str, df[df['size'] == i].index)
    unrecognized_with_i_size = [] 
    for cluster_id in clusters_with_i_size:
        if cluster_id in res:
            unrecognized_with_i_size.append(cluster_id)
    res_perc.append(1.0 * len(unrecognized_with_i_size)/len(clusters_with_i_size))
    
plt.bar(range(5,25), res_perc)
plt.xticks(range(5,25), range(5,25))
plt.show()

# %%
input_reads = '/Bmo/orange_nikita/GMC_compilation/GMC_3_IG/input3.fa'
ref_rcm_file = '/Bmo/orange_nikita/GMC_compilation/GMC_3_IG/repertoire3.rcm'
cons_rmc_nsp_file = '/Bmo/orange_nikita/GMC_compilation/GMC_3_IG/final_repertoire.rcm'
cons_rcm_file = '/Bmo/orange_nikita/GMC_compilation/splitted/GMC_3_IG_splitted.rcm'

# %%
id_dict = func_tools.id_to_read(input_reads)

ref_rcm = func_tools.read_rcm(ref_rcm_file)

cons_rcm = func_tools.read_rcm(cons_rcm_file)

ref_clusters = func_tools.construct_clusters(ref_rcm, id_dict)

cons_clusters = func_tools.construct_clusters(cons_rcm, id_dict)

rep = func_tools.clusters2rep(ref_clusters)

cons_rep = func_tools.clusters2rep(cons_clusters)

res = func_tools.find_unrecognized_clusters(rep, cons_rep)

df = func_tools.build_df(input_reads, ref_rcm_file, threshold=0)

# %%
plt.hist(df.ix[map(int, res)]['size'], bins=150)
plt.xlim((-5, 20))
plt.show()

# %%
res_perc = []
for i in range(5, 25):
    clusters_with_i_size = map(str, df[df['size'] == i].index)
    unrecognized_with_i_size = [] 
    for cluster_id in clusters_with_i_size:
        if cluster_id in res:
            unrecognized_with_i_size.append(cluster_id)
    res_perc.append(1.0 * len(unrecognized_with_i_size)/len(clusters_with_i_size))
    
plt.bar(range(5,25), res_perc)
plt.xticks(range(5,25), range(5,25))
plt.show()
